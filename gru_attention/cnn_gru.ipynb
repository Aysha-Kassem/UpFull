# %% [markdown]
# Final result

# %% [markdown]
# model name is BEST_BiGRU_Attention.keras

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import joblib
import matplotlib.pyplot as plt

# ==============================
# 1) DATA PREPROCESSING
# ==============================
def prepare_common_data(filepath='DataSet.csv', time_steps=50, test_size=0.2, step_size=2):
    df = pd.read_csv(filepath, low_memory=False)
    
    # Extract wrist sensor data
    df['WristAccelerometer_x'] = pd.to_numeric(df['WristAccelerometer'], errors='coerce')
    df['WristAccelerometer_y'] = pd.to_numeric(df['Unnamed: 30'], errors='coerce')
    df['WristAccelerometer_z'] = pd.to_numeric(df['Unnamed: 31'], errors='coerce')
    df['WristAngularVelocity_x'] = pd.to_numeric(df['WristAngularVelocity'], errors='coerce')
    df['WristAngularVelocity_y'] = pd.to_numeric(df['Unnamed: 33'], errors='coerce')
    df['WristAngularVelocity_z'] = pd.to_numeric(df['Unnamed: 34'], errors='coerce')

    FEATURES = ['WristAccelerometer_x','WristAccelerometer_y','WristAccelerometer_z',
                'WristAngularVelocity_x','WristAngularVelocity_y','WristAngularVelocity_z']

    # Magnitude
    df['Acc_mag'] = np.sqrt(df['WristAccelerometer_x']**2 +
                            df['WristAccelerometer_y']**2 +
                            df['WristAccelerometer_z']**2)
    df['Gyro_mag'] = np.sqrt(df['WristAngularVelocity_x']**2 +
                             df['WristAngularVelocity_y']**2 +
                             df['WristAngularVelocity_z']**2)
    FEATURES += ['Acc_mag','Gyro_mag']

    # Define Fall Now based on Tag
    FALL_CODES = [7,8,9,10,11]
    df['fall_now'] = df['Tag'].apply(lambda x: 1 if x in FALL_CODES else 0)

    # Fall Soon (predict within next HORIZON frames)
    HORIZON = 10
    fall_series = df['fall_now'].values
    df['fall_soon'] = [int(fall_series[i+1:i+HORIZON+1].max()) if i+HORIZON < len(fall_series) else 0
                       for i in range(len(fall_series))]

    df[FEATURES] = df[FEATURES].fillna(0)

    X = df[FEATURES].values
    y_now = df['fall_now'].values
    y_soon = df['fall_soon'].values

    X_train_raw, X_test_raw, y_train_now, y_test_now, y_train_soon, y_test_soon = train_test_split(
        X, y_now, y_soon, test_size=test_size, random_state=42, stratify=y_now
    )

    # Scaling
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_raw)
    X_test_scaled = scaler.transform(X_test_raw)
    joblib.dump(scaler, "scaler_all.save")

    # Sliding window
    def create_sequences(data, target, steps, step_size=1):
        X_seq, y_seq = [], []
        for i in range(0, len(data)-steps, step_size):
            X_seq.append(data[i:i+steps])
            y_seq.append(target[i+steps-1])
        return np.array(X_seq), np.array(y_seq)

    X_train, y_train_now_seq = create_sequences(X_train_scaled, y_train_now, time_steps, step_size)
    _, y_train_soon_seq = create_sequences(X_train_scaled, y_train_soon, time_steps, step_size)
    X_test, y_test_now_seq = create_sequences(X_test_scaled, y_test_now, time_steps, step_size)
    _, y_test_soon_seq = create_sequences(X_test_scaled, y_test_soon, time_steps, step_size)

    return X_train, X_test, y_train_now_seq, y_test_now_seq, y_train_soon_seq, y_test_soon_seq

# ==============================
# 2) ATTENTION BLOCK
# ==============================
def attention_block(inputs):
    score = layers.Dense(128, activation='tanh')(inputs)
    score = layers.Dense(1, activation='sigmoid')(score)
    attention = layers.Multiply()([inputs, score])
    context = layers.Lambda(lambda x: tf.reduce_sum(x, axis=1))(attention)
    return context

# ==============================
# 3) BUILD BiGRU + ATTENTION MODEL
# ==============================
def build_bigru_attention(time_steps, features):
    inp = Input(shape=(time_steps, features))
    x = layers.Bidirectional(layers.GRU(128, return_sequences=True))(inp)  # GRU فقط
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Bidirectional(layers.GRU(128, return_sequences=True))(x)  # GRU ثاني بدل LSTM
    x = layers.LayerNormalization()(x)
    att = attention_block(x)
    shared = layers.Dense(128, activation='relu')(att)
    shared = layers.Dropout(0.3)(shared)
    fall_now = layers.Dense(64, activation='relu')(shared)
    fall_now = layers.Dense(1, activation='sigmoid', name='fall_now')(fall_now)
    fall_soon = layers.Dense(64, activation='relu')(shared)
    fall_soon = layers.Dense(1, activation='sigmoid', name='fall_soon')(fall_soon)
    
    model = Model(inp, [fall_now, fall_soon])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(0.0008),
        loss='binary_crossentropy',
        metrics={
            "fall_now": ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
            "fall_soon": ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
        }
    )
    return model

# ==============================
# 4) TRAINING FUNCTION + EVALUATION
# ==============================
def train_bigru_attention():
    X_train, X_test, y_train_now, y_test_now, y_train_soon, y_test_soon = prepare_common_data()
    
    model = build_bigru_attention(X_train.shape[1], X_train.shape[2])
    print(model.summary())

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.4, patience=4),
        ModelCheckpoint("BEST_BiGRU_Attention.keras", save_best_only=True, monitor='val_loss')
    ]

    history = model.fit(
        X_train,
        {"fall_now": y_train_now, "fall_soon": y_train_soon},
        validation_data=(X_test, {"fall_now": y_test_now, "fall_soon": y_test_soon}),
        epochs=80,
        batch_size=128,
        callbacks=callbacks,
        verbose=1
    )

    model.save("FINAL_BiGRU_Attention.keras")

    # ==============================
    # Predictions & Metrics
    # ==============================
    y_pred_now, y_pred_soon = model.predict(X_test)
    y_pred_now = (y_pred_now>0.5).astype(int)
    y_pred_soon = (y_pred_soon>0.5).astype(int)

    for label, y_true, y_pred in [("Fall Now", y_test_now, y_pred_now), ("Fall Soon", y_test_soon, y_pred_soon)]:
        print(f"\n=== Metrics for {label} ===")
        print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
        print(f"Precision: {precision_score(y_true, y_pred):.4f}")
        print(f"Recall: {recall_score(y_true, y_pred):.4f}")
        print(f"F1-Score: {f1_score(y_true, y_pred):.4f}")
        ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred)).plot(cmap="Blues")
        plt.title(f"Confusion Matrix - {label}")
        plt.show()

    return model, history, X_test, y_test_now, y_test_soon

# ==============================
# 5) MAIN
# ==============================
if __name__=="__main__":
    train_bigru_attention()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11      │ (None, 50, 8)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_8     │ (None, 50, 256)   │    105,984 │ input_layer_11[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 256)   │        512 │ bidirectional_8[… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 50, 256)   │          0 │ layer_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_9     │ (None, 50, 256)   │    296,448 │ dropout_29[0][0]  │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 50, 256)   │        512 │ bidirectional_9[… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 50, 128)   │     32,896 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 50, 1)     │        129 │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 50, 256)   │          0 │ layer_normalizat… │
# │ (Multiply)          │                   │            │ dense_18[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 256)       │          0 │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 128)       │     32,896 │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 128)       │          0 │ dense_19[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 64)        │      8,256 │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 64)        │      8,256 │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fall_now (Dense)    │ (None, 1)         │         65 │ dense_20[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fall_soon (Dense)   │ (None, 1)         │         65 │ dense_21[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 486,019 (1.85 MB)
#  Trainable params: 486,019 (1.85 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 356s 376ms/step - fall_now_accuracy: 0.7810 - fall_now_loss: 0.6099 - fall_now_precision_2: 0.8007 - fall_now_recall_2: 0.9601 - fall_soon_accuracy: 0.7879 - fall_soon_loss: 0.5034 - fall_soon_precision_3: 0.7985 - fall_soon_recall_3: 0.9785 - loss: 1.1133 - val_fall_now_accuracy: 0.8829 - val_fall_now_loss: 0.2783 - val_fall_now_precision_2: 0.9160 - val_fall_now_recall_2: 0.9364 - val_fall_soon_accuracy: 0.8862 - val_fall_soon_loss: 0.2788 - val_fall_soon_precision_3: 0.9192 - val_fall_soon_recall_3: 0.9386 - val_loss: 0.5568 - learning_rate: 8.0000e-04
# Epoch 2/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 344s 373ms/step - fall_now_accuracy: 0.8838 - fall_now_loss: 0.2664 - fall_now_precision_2: 0.9284 - fall_now_recall_2: 0.9220 - fall_soon_accuracy: 0.8880 - fall_soon_loss: 0.2605 - fall_soon_precision_3: 0.9358 - fall_soon_recall_3: 0.9209 - loss: 0.5269 - val_fall_now_accuracy: 0.8996 - val_fall_now_loss: 0.2302 - val_fall_now_precision_2: 0.9181 - val_fall_now_recall_2: 0.9573 - val_fall_soon_accuracy: 0.9041 - val_fall_soon_loss: 0.2210 - val_fall_soon_precision_3: 0.9239 - val_fall_soon_recall_3: 0.9575 - val_loss: 0.4495 - learning_rate: 8.0000e-04
# Epoch 3/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 344s 374ms/step - fall_now_accuracy: 0.9012 - fall_now_loss: 0.2324 - fall_now_precision_2: 0.9323 - fall_now_recall_2: 0.9416 - fall_soon_accuracy: 0.9065 - fall_soon_loss: 0.2216 - fall_soon_precision_3: 0.9383 - fall_soon_recall_3: 0.9433 - loss: 0.4540 - val_fall_now_accuracy: 0.9065 - val_fall_now_loss: 0.2170 - val_fall_now_precision_2: 0.9478 - val_fall_now_recall_2: 0.9320 - val_fall_soon_accuracy: 0.9108 - val_fall_soon_loss: 0.2089 - val_fall_soon_precision_3: 0.9516 - val_fall_soon_recall_3: 0.9347 - val_loss: 0.4263 - learning_rate: 8.0000e-04
# Epoch 4/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 332s 361ms/step - fall_now_accuracy: 0.9048 - fall_now_loss: 0.2201 - fall_now_precision_2: 0.9355 - fall_now_recall_2: 0.9430 - fall_soon_accuracy: 0.9090 - fall_soon_loss: 0.2115 - fall_soon_precision_3: 0.9394 - fall_soon_recall_3: 0.9456 - loss: 0.4316 - val_fall_now_accuracy: 0.9091 - val_fall_now_loss: 0.2117 - val_fall_now_precision_2: 0.9309 - val_fall_now_recall_2: 0.9548 - val_fall_soon_accuracy: 0.9127 - val_fall_soon_loss: 0.2039 - val_fall_soon_precision_3: 0.9353 - val_fall_soon_recall_3: 0.9557 - val_loss: 0.4147 - learning_rate: 8.0000e-04
# Epoch 5/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 342s 371ms/step - fall_now_accuracy: 0.9112 - fall_now_loss: 0.2106 - fall_now_precision_2: 0.9395 - fall_now_recall_2: 0.9474 - fall_soon_accuracy: 0.9150 - fall_soon_loss: 0.2023 - fall_soon_precision_3: 0.9443 - fall_soon_recall_3: 0.9483 - loss: 0.4130 - val_fall_now_accuracy: 0.9118 - val_fall_now_loss: 0.2093 - val_fall_now_precision_2: 0.9467 - val_fall_now_recall_2: 0.9403 - val_fall_soon_accuracy: 0.9149 - val_fall_soon_loss: 0.2008 - val_fall_soon_precision_3: 0.9484 - val_fall_soon_recall_3: 0.9437 - val_loss: 0.4109 - learning_rate: 8.0000e-04
# Epoch 6/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 354s 384ms/step - fall_now_accuracy: 0.9133 - fall_now_loss: 0.2047 - fall_now_precision_2: 0.9413 - fall_now_recall_2: 0.9478 - fall_soon_accuracy: 0.9165 - fall_soon_loss: 0.1954 - fall_soon_precision_3: 0.9453 - fall_soon_recall_3: 0.9491 - loss: 0.4002 - val_fall_now_accuracy: 0.9122 - val_fall_now_loss: 0.2039 - val_fall_now_precision_2: 0.9417 - val_fall_now_recall_2: 0.9465 - val_fall_soon_accuracy: 0.9158 - val_fall_soon_loss: 0.1956 - val_fall_soon_precision_3: 0.9470 - val_fall_soon_recall_3: 0.9465 - val_loss: 0.4006 - learning_rate: 8.0000e-04
# Epoch 7/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 364s 395ms/step - fall_now_accuracy: 0.9156 - fall_now_loss: 0.2023 - fall_now_precision_2: 0.9410 - fall_now_recall_2: 0.9511 - fall_soon_accuracy: 0.9198 - fall_soon_loss: 0.1929 - fall_soon_precision_3: 0.9462 - fall_soon_recall_3: 0.9521 - loss: 0.3952 - val_fall_now_accuracy: 0.9118 - val_fall_now_loss: 0.2070 - val_fall_now_precision_2: 0.9528 - val_fall_now_recall_2: 0.9337 - val_fall_soon_accuracy: 0.9168 - val_fall_soon_loss: 0.1980 - val_fall_soon_precision_3: 0.9555 - val_fall_soon_recall_3: 0.9384 - val_loss: 0.4053 - learning_rate: 8.0000e-04
# Epoch 8/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 376s 408ms/step - fall_now_accuracy: 0.9156 - fall_now_loss: 0.1973 - fall_now_precision_2: 0.9421 - fall_now_recall_2: 0.9501 - fall_soon_accuracy: 0.9194 - fall_soon_loss: 0.1892 - fall_soon_precision_3: 0.9458 - fall_soon_recall_3: 0.9523 - loss: 0.3865 - val_fall_now_accuracy: 0.9132 - val_fall_now_loss: 0.2027 - val_fall_now_precision_2: 0.9305 - val_fall_now_recall_2: 0.9609 - val_fall_soon_accuracy: 0.9163 - val_fall_soon_loss: 0.1955 - val_fall_soon_precision_3: 0.9350 - val_fall_soon_recall_3: 0.9610 - val_loss: 0.3993 - learning_rate: 8.0000e-04
# Epoch 9/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 398s 432ms/step - fall_now_accuracy: 0.9171 - fall_now_loss: 0.1946 - fall_now_precision_2: 0.9423 - fall_now_recall_2: 0.9521 - fall_soon_accuracy: 0.9207 - fall_soon_loss: 0.1844 - fall_soon_precision_3: 0.9464 - fall_soon_recall_3: 0.9534 - loss: 0.3790 - val_fall_now_accuracy: 0.9143 - val_fall_now_loss: 0.2030 - val_fall_now_precision_2: 0.9461 - val_fall_now_recall_2: 0.9444 - val_fall_soon_accuracy: 0.9176 - val_fall_soon_loss: 0.1955 - val_fall_soon_precision_3: 0.9502 - val_fall_soon_recall_3: 0.9452 - val_loss: 0.3988 - learning_rate: 8.0000e-04
# Epoch 10/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 398s 432ms/step - fall_now_accuracy: 0.9202 - fall_now_loss: 0.1889 - fall_now_precision_2: 0.9434 - fall_now_recall_2: 0.9548 - fall_soon_accuracy: 0.9244 - fall_soon_loss: 0.1785 - fall_soon_precision_3: 0.9483 - fall_soon_recall_3: 0.9562 - loss: 0.3674 - val_fall_now_accuracy: 0.9145 - val_fall_now_loss: 0.2019 - val_fall_now_precision_2: 0.9477 - val_fall_now_recall_2: 0.9429 - val_fall_soon_accuracy: 0.9180 - val_fall_soon_loss: 0.1942 - val_fall_soon_precision_3: 0.9520 - val_fall_soon_recall_3: 0.9439 - val_loss: 0.3967 - learning_rate: 8.0000e-04
# Epoch 11/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 413s 448ms/step - fall_now_accuracy: 0.9223 - fall_now_loss: 0.1829 - fall_now_precision_2: 0.9464 - fall_now_recall_2: 0.9542 - fall_soon_accuracy: 0.9271 - fall_soon_loss: 0.1732 - fall_soon_precision_3: 0.9516 - fall_soon_recall_3: 0.9560 - loss: 0.3561 - val_fall_now_accuracy: 0.9146 - val_fall_now_loss: 0.2032 - val_fall_now_precision_2: 0.9439 - val_fall_now_recall_2: 0.9472 - val_fall_soon_accuracy: 0.9178 - val_fall_soon_loss: 0.1950 - val_fall_soon_precision_3: 0.9489 - val_fall_soon_recall_3: 0.9471 - val_loss: 0.3994 - learning_rate: 8.0000e-04
# Epoch 12/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 410s 445ms/step - fall_now_accuracy: 0.9243 - fall_now_loss: 0.1779 - fall_now_precision_2: 0.9474 - fall_now_recall_2: 0.9562 - fall_soon_accuracy: 0.9280 - fall_soon_loss: 0.1684 - fall_soon_precision_3: 0.9520 - fall_soon_recall_3: 0.9570 - loss: 0.3463 - val_fall_now_accuracy: 0.9146 - val_fall_now_loss: 0.2036 - val_fall_now_precision_2: 0.9404 - val_fall_now_recall_2: 0.9513 - val_fall_soon_accuracy: 0.9173 - val_fall_soon_loss: 0.1962 - val_fall_soon_precision_3: 0.9447 - val_fall_soon_recall_3: 0.9511 - val_loss: 0.4011 - learning_rate: 8.0000e-04
# Epoch 13/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 425s 462ms/step - fall_now_accuracy: 0.9280 - fall_now_loss: 0.1716 - fall_now_precision_2: 0.9488 - fall_now_recall_2: 0.9595 - fall_soon_accuracy: 0.9316 - fall_soon_loss: 0.1631 - fall_soon_precision_3: 0.9534 - fall_soon_recall_3: 0.9602 - loss: 0.3346 - val_fall_now_accuracy: 0.9136 - val_fall_now_loss: 0.2045 - val_fall_now_precision_2: 0.9478 - val_fall_now_recall_2: 0.9416 - val_fall_soon_accuracy: 0.9178 - val_fall_soon_loss: 0.1964 - val_fall_soon_precision_3: 0.9532 - val_fall_soon_recall_3: 0.9423 - val_loss: 0.4018 - learning_rate: 8.0000e-04
# Epoch 14/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 432s 469ms/step - fall_now_accuracy: 0.9293 - fall_now_loss: 0.1691 - fall_now_precision_2: 0.9516 - fall_now_recall_2: 0.9581 - fall_soon_accuracy: 0.9323 - fall_soon_loss: 0.1608 - fall_soon_precision_3: 0.9555 - fall_soon_recall_3: 0.9589 - loss: 0.3299 - val_fall_now_accuracy: 0.9135 - val_fall_now_loss: 0.2116 - val_fall_now_precision_2: 0.9495 - val_fall_now_recall_2: 0.9396 - val_fall_soon_accuracy: 0.9163 - val_fall_soon_loss: 0.2048 - val_fall_soon_precision_3: 0.9553 - val_fall_soon_recall_3: 0.9380 - val_loss: 0.4176 - learning_rate: 8.0000e-04
# Epoch 15/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 435s 473ms/step - fall_now_accuracy: 0.9350 - fall_now_loss: 0.1550 - fall_now_precision_2: 0.9529 - fall_now_recall_2: 0.9643 - fall_soon_accuracy: 0.9392 - fall_soon_loss: 0.1461 - fall_soon_precision_3: 0.9582 - fall_soon_recall_3: 0.9649 - loss: 0.3011 - val_fall_now_accuracy: 0.9139 - val_fall_now_loss: 0.2128 - val_fall_now_precision_2: 0.9416 - val_fall_now_recall_2: 0.9489 - val_fall_soon_accuracy: 0.9175 - val_fall_soon_loss: 0.2040 - val_fall_soon_precision_3: 0.9454 - val_fall_soon_recall_3: 0.9506 - val_loss: 0.4179 - learning_rate: 3.2000e-04
# Epoch 16/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 451s 490ms/step - fall_now_accuracy: 0.9386 - fall_now_loss: 0.1460 - fall_now_precision_2: 0.9573 - fall_now_recall_2: 0.9645 - fall_soon_accuracy: 0.9425 - fall_soon_loss: 0.1366 - fall_soon_precision_3: 0.9615 - fall_soon_recall_3: 0.9659 - loss: 0.2826 - val_fall_now_accuracy: 0.9132 - val_fall_now_loss: 0.2114 - val_fall_now_precision_2: 0.9415 - val_fall_now_recall_2: 0.9482 - val_fall_soon_accuracy: 0.9167 - val_fall_soon_loss: 0.2040 - val_fall_soon_precision_3: 0.9457 - val_fall_soon_recall_3: 0.9491 - val_loss: 0.4170 - learning_rate: 3.2000e-04
# Epoch 17/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 454s 493ms/step - fall_now_accuracy: 0.9408 - fall_now_loss: 0.1419 - fall_now_precision_2: 0.9578 - fall_now_recall_2: 0.9666 - fall_soon_accuracy: 0.9445 - fall_soon_loss: 0.1332 - fall_soon_precision_3: 0.9620 - fall_soon_recall_3: 0.9678 - loss: 0.2751 - val_fall_now_accuracy: 0.9142 - val_fall_now_loss: 0.2205 - val_fall_now_precision_2: 0.9432 - val_fall_now_recall_2: 0.9476 - val_fall_soon_accuracy: 0.9176 - val_fall_soon_loss: 0.2119 - val_fall_soon_precision_3: 0.9472 - val_fall_soon_recall_3: 0.9486 - val_loss: 0.4339 - learning_rate: 3.2000e-04
# Epoch 18/80
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 476s 517ms/step - fall_now_accuracy: 0.9435 - fall_now_loss: 0.1344 - fall_now_precision_2: 0.9597 - fall_now_recall_2: 0.9682 - fall_soon_accuracy: 0.9474 - fall_soon_loss: 0.1264 - fall_soon_precision_3: 0.9632 - fall_soon_recall_3: 0.9702 - loss: 0.2608 - val_fall_now_accuracy: 0.9123 - val_fall_now_loss: 0.2249 - val_fall_now_precision_2: 0.9423 - val_fall_now_recall_2: 0.9460 - val_fall_soon_accuracy: 0.9169 - val_fall_soon_loss: 0.2159 - val_fall_soon_precision_3: 0.9474 - val_fall_soon_recall_3: 0.9474 - val_loss: 0.4425 - learning_rate: 3.2000e-04
# 921/921 ━━━━━━━━━━━━━━━━━━━━ 37s 39ms/step
#
# === Metrics for Fall Now ===
# Accuracy: 0.9145
# Precision: 0.9477
# Recall: 0.9429
# F1-Score: 0.9453
# === Metrics for Fall Soon ===
# Accuracy: 0.9180
# Precision: 0.9520
# Recall: 0.9439
# F1-Score: 0.9479

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\programdata\miniconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (3.9.1)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\programdata\miniconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\miniconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\programdata\miniconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\programdata\miniconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\programdata\miniconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\miniconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\miniconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\miniconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\miniconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\programdata\miniconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\miniconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\miniconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\miniconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\miniconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\miniconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# preprocessing trial

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import StandardScaler

def prepare_common_data(filepath='DataSet.csv', time_steps=50, test_size=0.2, step_size=2):

    df = pd.read_csv(filepath, low_memory=False)

    # ============================
    # 1) استخراج الحساسات
    # ============================
    df['WristAccelerometer_x'] = pd.to_numeric(df['WristAccelerometer'], errors='coerce')
    df['WristAccelerometer_y'] = pd.to_numeric(df['Unnamed: 30'], errors='coerce')
    df['WristAccelerometer_z'] = pd.to_numeric(df['Unnamed: 31'], errors='coerce')

    df['WristAngularVelocity_x'] = pd.to_numeric(df['WristAngularVelocity'], errors='coerce')
    df['WristAngularVelocity_y'] = pd.to_numeric(df['Unnamed: 33'], errors='coerce')
    df['WristAngularVelocity_z'] = pd.to_numeric(df['Unnamed: 34'], errors='coerce')

    FEATURES = [
        'WristAccelerometer_x','WristAccelerometer_y','WristAccelerometer_z',
        'WristAngularVelocity_x','WristAngularVelocity_y','WristAngularVelocity_z'
    ]

    # Magnitudes
    df['Acc_mag'] = np.sqrt(df['WristAccelerometer_x']**2 +
                            df['WristAccelerometer_y']**2 +
                            df['WristAccelerometer_z']**2)
    df['Gyro_mag'] = np.sqrt(df['WristAngularVelocity_x']**2 +
                             df['WristAngularVelocity_y']**2 +
                             df['WristAngularVelocity_z']**2)
    FEATURES += ['Acc_mag','Gyro_mag']

    # ============================
    # 2) Labels (fall now + fall soon)
    # ============================
    FALL_CODES = [7,8,9,10,11]

    df['fall_now'] = df['Activity'].apply(lambda x: 1 if x in FALL_CODES else 0)

    HORIZON = 10
    fall_series = df['fall_now'].values

    df['fall_soon'] = [
        int(fall_series[i+1:i+HORIZON+1].max()) if i+HORIZON < len(fall_series)
        else 0
        for i in range(len(fall_series))
    ]

    # ============================
    # 3) Fill missing values
    # ============================
    df[FEATURES] = df[FEATURES].fillna(0)

    # ============================
    # 4) بدل train_test_split >>> split زمني صح
    # ============================
    split_index = int(len(df) * (1 - test_size))

    train_df = df.iloc[:split_index].reset_index(drop=True)
    test_df  = df.iloc[split_index:].reset_index(drop=True)

    # ============================
    # 5) Scaling على Train فقط
    # ============================
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(train_df[FEATURES].values)
    X_test_scaled  = scaler.transform(test_df[FEATURES].values)

    joblib.dump(scaler, "scaler_all.save")

    y_now_train = train_df['fall_now'].values
    y_now_test  = test_df['fall_now'].values

    y_soon_train = train_df['fall_soon'].values
    y_soon_test  = test_df['fall_soon'].values

    # ============================
    # 6) Sliding Window Function
    # ============================
    def create_sequences(data, target, steps, step_size):
        X_seq, y_seq = [], []
        for i in range(0, len(data) - steps, step_size):
            X_seq.append(data[i:i + steps])
            y_seq.append(target[i + steps - 1])
        return np.array(X_seq), np.array(y_seq)

    # ============================
    # 7) Apply windowing correctly
    # ============================
    X_train, y_now_train_seq = create_sequences(
        X_train_scaled, y_now_train, time_steps, step_size)

    _, y_soon_train_seq = create_sequences(
        X_train_scaled, y_soon_train, time_steps, step_size)

    X_test, y_now_test_seq = create_sequences(
        X_test_scaled, y_now_test, time_steps, step_size)

    _, y_soon_test_seq = create_sequences(
        X_test_scaled, y_soon_test, time_steps, step_size)

    return X_train, X_test, y_now_train_seq, y_now_test_seq, y_soon_train_seq, y_soon_test_seq

# %% [markdown]
# ##now

# %%
X_train, X_test, y_train, y_test, _, _ = prepare_common_data()

# %% [markdown]
# ##soon

# %%
#X_train, X_test, _, _, y_train, y_test = prepare_common_data(...)

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Dropout, GRU, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import regularizers

# ---------------------------
# 1) استدعي الداتا المُحضّرة
# ---------------------------
# X_train, X_test, y_train, y_test, _, _ = prepare_common_data(...)

# ---------- Check shapes ----------
print("X_train shape:", X_train.shape)
print("X_test  shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test  shape:", y_test.shape)

time_steps = X_train.shape[1]
n_features = X_train.shape[2]

# ---------------------------
# 2) حساب class weights
# ---------------------------
classes = np.unique(y_train)
class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weight_dict = {int(c): w for c, w in zip(classes, class_weights)}
print("Class weights:", class_weight_dict)

# ---------------------------
# 3) بناء الموديل مع regularization و higher dropout
# ---------------------------
def build_model(time_steps, n_features, dropout_rate=0.5):
    inp = Input(shape=(time_steps, n_features))
    
    x = Conv1D(64, kernel_size=5, padding='same', activation='relu',
               kernel_regularizer=regularizers.l2(0.001))(inp)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    x = Conv1D(128, kernel_size=3, padding='same', activation='relu',
               kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    x = Conv1D(64, kernel_size=3, padding='same', activation='relu',
               kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    x = GRU(128, return_sequences=False, kernel_regularizer=regularizers.l2(0.001))(x)
    x = Dropout(dropout_rate)(x)

    out = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=inp, outputs=out)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
    return model

model = build_model(time_steps, n_features)
model.summary()

# ---------------------------
# 4) Callbacks
# ---------------------------
checkpoint_path = 'best_model.h5'
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
    ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1, min_lr=1e-6)
]

# ---------------------------
# 5) Training
# ---------------------------
BATCH_SIZE = 64
EPOCHS = 100

history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    class_weight=class_weight_dict,
    verbose=2
)

model.save('final_model.h5')

# ---------------------------
# 6) Evaluation
# ---------------------------
y_prob = model.predict(X_test, batch_size=256).ravel()
y_pred = (y_prob >= 0.5).astype(int)

print("ROC AUC:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_test, y_prob):.3f}")
plt.plot([0,1],[0,1],'--', alpha=0.5)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
# Out:
# X_train shape: (117847, 50, 8)
# X_test  shape: (29443, 50, 8)
# y_train shape: (117847,)
# y_test  shape: (29443,)
# Class weights: {0: 1.4170434322543408, 1: 0.7726152232347735}
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 50, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 50, 64)         │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 50, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 50, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 50, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 50, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 50, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 50, 64)         │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 50, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 50, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 128)            │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 127,617 (498.50 KB)
#  Trainable params: 127,105 (496.50 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.52530, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1658/1658 - 61s - 37ms/step - accuracy: 0.8415 - auc: 0.8990 - loss: 0.5387 - val_accuracy: 0.8230 - val_auc: 0.9109 - val_loss: 0.5253 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.52530 to 0.41550, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1658/1658 - 55s - 33ms/step - accuracy: 0.8959 - auc: 0.9564 - loss: 0.3314 - val_accuracy: 0.8412 - val_auc: 0.9423 - val_loss: 0.4155 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.41550
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9123 - auc: 0.9678 - loss: 0.2873 - val_accuracy: 0.8588 - val_auc: 0.9589 - val_loss: 0.4351 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.41550
# 1658/1658 - 57s - 34ms/step - accuracy: 0.9232 - auc: 0.9746 - loss: 0.2651 - val_accuracy: 0.7816 - val_auc: 0.9330 - val_loss: 0.6478 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.41550 to 0.38596, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9313 - auc: 0.9795 - loss: 0.2466 - val_accuracy: 0.8846 - val_auc: 0.9678 - val_loss: 0.3860 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.38596 to 0.35684, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9353 - auc: 0.9820 - loss: 0.2349 - val_accuracy: 0.9118 - val_auc: 0.9628 - val_loss: 0.3568 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.35684
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9369 - auc: 0.9830 - loss: 0.2303 - val_accuracy: 0.8990 - val_auc: 0.9654 - val_loss: 0.3802 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.35684
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9401 - auc: 0.9845 - loss: 0.2232 - val_accuracy: 0.8274 - val_auc: 0.9357 - val_loss: 0.6304 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.35684
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9428 - auc: 0.9858 - loss: 0.2154 - val_accuracy: 0.8554 - val_auc: 0.9443 - val_loss: 0.5801 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.35684
# 1658/1658 - 54s - 33ms/step - accuracy: 0.9547 - auc: 0.9908 - loss: 0.1765 - val_accuracy: 0.8105 - val_auc: 0.9423 - val_loss: 0.6128 - learning_rate: 5.0000e-04
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.35684
# 1658/1658 - 54s - 33ms/step - accuracy: 0.9545 - auc: 0.9912 - loss: 0.1679 - val_accuracy: 0.8157 - val_auc: 0.9452 - val_loss: 0.6862 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step
# ROC AUC: 0.9147747293691866
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75      8654
#            1       0.91      0.85      0.88     20789
#
#     accuracy                           0.84     29443
#    macro avg       0.80      0.83      0.81     29443
# weighted avg       0.85      0.84      0.84     29443
#
# Confusion Matrix:
#  [[ 6989  1665]
#  [ 3057 17732]]

# %% [markdown]
# trial

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Dropout, GRU, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import regularizers

# ---------------------------
# 1) استدعي الداتا المُحضّرة
# ---------------------------
# X_train, X_test, y_train, y_test, _, _ = prepare_common_data(...)

time_steps = X_train.shape[1]
n_features = X_train.shape[2]

# ---------------------------
# 2) حساب class weights
# ---------------------------
classes = np.unique(y_train)
class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weight_dict = {int(c): w for c, w in zip(classes, class_weights)}

# ---------------------------
# 3) بناء الموديل
# ---------------------------
def build_model(time_steps, n_features, dropout_rate=0.5):
    inp = Input(shape=(time_steps, n_features))
    x = Conv1D(64, kernel_size=5, padding='same', activation='relu',
               kernel_regularizer=regularizers.l2(0.001))(inp)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    x = Conv1D(128, kernel_size=3, padding='same', activation='relu',
               kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    x = Conv1D(64, kernel_size=3, padding='same', activation='relu',
               kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    x = GRU(128, return_sequences=False, kernel_regularizer=regularizers.l2(0.001))(x)
    x = Dropout(dropout_rate)(x)

    out = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=inp, outputs=out)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
    return model

model = build_model(time_steps, n_features)
model.summary()

# ---------------------------
# 4) Callbacks
# ---------------------------
checkpoint_path = 'best_model.h5'
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
    ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1, min_lr=1e-6)
]

# ---------------------------
# 5) Training
# ---------------------------
history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    class_weight=class_weight_dict,
    verbose=2
)

# احفظ الموديل النهائي باسم مختلف
model.save('final_model_v2.h5')

# ---------------------------
# 6) Evaluation + threshold tuning
# ---------------------------
y_prob = model.predict(X_test, batch_size=256).ravel()
y_pred_05 = (y_prob >= 0.5).astype(int)

# ROC & g-mean tuning
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
gmeans = np.sqrt(tpr * (1 - fpr))
ix = np.argmax(gmeans)
best_thresh = thresholds[ix]
print("Best threshold (g-mean):", best_thresh)

y_pred_best = (y_prob >= best_thresh).astype(int)

print("ROC AUC:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n", classification_report(y_test, y_pred_best))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_best))

# رسم ROC curve
plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_test, y_prob):.3f}")
plt.plot([0,1],[0,1],'--', alpha=0.5)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 50, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 50, 64)         │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 50, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 50, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 50, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 50, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 50, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 50, 64)         │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 50, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 50, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 128)            │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 127,617 (498.50 KB)
#  Trainable params: 127,105 (496.50 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.40102, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1658/1658 - 63s - 38ms/step - accuracy: 0.8485 - auc: 0.9037 - loss: 0.5264 - val_accuracy: 0.8710 - val_auc: 0.9376 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.40102 to 0.33069, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1658/1658 - 55s - 33ms/step - accuracy: 0.8987 - auc: 0.9569 - loss: 0.3292 - val_accuracy: 0.8753 - val_auc: 0.9565 - val_loss: 0.3307 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.33069
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9137 - auc: 0.9683 - loss: 0.2853 - val_accuracy: 0.8617 - val_auc: 0.9165 - val_loss: 0.4558 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.33069
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9215 - auc: 0.9734 - loss: 0.2661 - val_accuracy: 0.8878 - val_auc: 0.9581 - val_loss: 0.3711 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.33069
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1658/1658 - 56s - 34ms/step - accuracy: 0.9279 - auc: 0.9775 - loss: 0.2514 - val_accuracy: 0.9003 - val_auc: 0.9618 - val_loss: 0.4058 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.33069
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9433 - auc: 0.9862 - loss: 0.2047 - val_accuracy: 0.8333 - val_auc: 0.9420 - val_loss: 0.5051 - learning_rate: 5.0000e-04
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.33069
# 1658/1658 - 55s - 33ms/step - accuracy: 0.9479 - auc: 0.9883 - loss: 0.1877 - val_accuracy: 0.7639 - val_auc: 0.8953 - val_loss: 0.9279 - learning_rate: 5.0000e-04
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step
# Best threshold (g-mean): 0.5194105
# ROC AUC: 0.901408787222065
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75      8654
#            1       0.89      0.90      0.90     20789
#
#     accuracy                           0.86     29443
#    macro avg       0.83      0.82      0.83     29443
# weighted avg       0.85      0.86      0.86     29443
#
# Confusion Matrix:
#  [[ 6434  2220]
#  [ 2028 18761]]

# %% [markdown]
# trial

# %%
# model_train_eval_infer_gru_improved.py
import numpy as np
import matplotlib.pyplot as plt
import joblib
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Dropout, GRU, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from collections import deque

# ---------------------------
# 1) استدعاء الداتا المُحضّرة
# ---------------------------
# من prepare_common_data.py
# X_train, X_test, y_now_train_seq, y_now_test_seq, y_soon_train_seq, y_soon_test_seq = prepare_common_data(...)

# استخدم y_soon* لو هدفك predict "fall soon"
X_train, X_test, y_train, y_test, _, _ = prepare_common_data(
    filepath='DataSet.csv', time_steps=50, test_size=0.2, step_size=2
)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

time_steps = X_train.shape[1]
n_features = X_train.shape[2]

# ---------------------------
# 2) Class weights أعلى للـ fall
# ---------------------------
class_weight_dict = {0: 1.0, 1: 2.0}  # بدل balanced
print("Class weights:", class_weight_dict)

# ---------------------------
# 3) بناء الموديل: Conv1D + Stacked GRU
# ---------------------------
def build_model(time_steps, n_features, dropout_rate=0.3):
    inp = Input(shape=(time_steps, n_features))
    
    # Conv layers
    x = Conv1D(64, kernel_size=5, padding='same', activation='relu')(inp)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    x = Conv1D(128, kernel_size=3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    # Stacked GRU
    x = GRU(128, return_sequences=True)(x)
    x = Dropout(dropout_rate)(x)
    x = GRU(64, return_sequences=False)(x)
    x = Dropout(dropout_rate)(x)
    
    out = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=inp, outputs=out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss='binary_crossentropy',
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )
    return model

model = build_model(time_steps, n_features, dropout_rate=0.3)
model.summary()

# ---------------------------
# 4) Callbacks
# ---------------------------
checkpoint_path = 'best_model_gru.h5'
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1, min_lr=1e-6)
]

# ---------------------------
# 5) Training
# ---------------------------
BATCH_SIZE = 64
EPOCHS = 100

history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    class_weight=class_weight_dict,
    verbose=2
)

# حفظ الموديل النهائي
model.save('final_model_gru.h5')

# ---------------------------
# 6) Evaluation
# ---------------------------
y_prob = model.predict(X_test, batch_size=256).ravel()

# Threshold tuning
best_thresh = 0.48  # جرب 0.48-0.50 لزيادة recall
y_pred = (y_prob >= best_thresh).astype(int)

print("ROC AUC:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

# رسم ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_test, y_prob):.3f}")
plt.plot([0,1], [0,1], '--', alpha=0.5)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# ---------------------------
# 7) Real-time inference helper مع Sliding Window Voting
# ---------------------------
scaler = joblib.load('scaler_all.save')  # من prepare_common_data

def realtime_predict(window_raw):
    """
    window_raw: np.array shape (time_steps, n_features) raw features (not scaled)
    returns: probability, binary decision
    """
    flat = window_raw.reshape(-1, n_features)
    flat_scaled = scaler.transform(flat)
    window_scaled = flat_scaled.reshape(1, time_steps, n_features)
    prob = model.predict(window_scaled)[0,0]
    pred = int(prob >= best_thresh)
    return prob, pred

# مثال Sliding Window Voting
vote_buffer = deque(maxlen=3)  # خذ آخر 3 predictions
def sliding_window_decision(window_raw):
    prob, pred = realtime_predict(window_raw)
    vote_buffer.append(pred)
    final_pred = int(sum(vote_buffer) >= 2)  # majority vote
    return prob, final_pred
# Out:
# X_train shape: (117847, 50, 8)
# X_test shape: (29443, 50, 8)
# y_train shape: (117847,)
# y_test shape: (29443,)
# Class weights: {0: 1.0, 1: 2.0}
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 50, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 50, 64)         │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 50, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 50, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 50, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 50, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 50, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 50, 64)         │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 50, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 50, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 50, 128)        │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 50, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_4 (GRU)                     │ (None, 64)             │        37,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 164,801 (643.75 KB)
#  Trainable params: 164,289 (641.75 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.30513, saving model to best_model_gru.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1658/1658 - 89s - 53ms/step - accuracy: 0.8694 - auc: 0.9262 - loss: 0.4108 - val_accuracy: 0.8616 - val_auc: 0.9503 - val_loss: 0.3051 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.30513 to 0.28294, saving model to best_model_gru.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1658/1658 - 82s - 50ms/step - accuracy: 0.9274 - auc: 0.9739 - loss: 0.2387 - val_accuracy: 0.8883 - val_auc: 0.9568 - val_loss: 0.2829 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.28294
# 1658/1658 - 83s - 50ms/step - accuracy: 0.9445 - auc: 0.9830 - loss: 0.1869 - val_accuracy: 0.8801 - val_auc: 0.9517 - val_loss: 0.3715 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.28294
# 1658/1658 - 80s - 48ms/step - accuracy: 0.9533 - auc: 0.9872 - loss: 0.1593 - val_accuracy: 0.8749 - val_auc: 0.9406 - val_loss: 0.4091 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.28294
# 1658/1658 - 82s - 49ms/step - accuracy: 0.9600 - auc: 0.9901 - loss: 0.1390 - val_accuracy: 0.8702 - val_auc: 0.9259 - val_loss: 0.4796 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.28294
# 1658/1658 - 80s - 49ms/step - accuracy: 0.9635 - auc: 0.9917 - loss: 0.1241 - val_accuracy: 0.8838 - val_auc: 0.9108 - val_loss: 0.4777 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.28294
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1658/1658 - 87s - 53ms/step - accuracy: 0.9686 - auc: 0.9937 - loss: 0.1089 - val_accuracy: 0.7625 - val_auc: 0.9080 - val_loss: 0.5984 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.28294
# 1658/1658 - 81s - 49ms/step - accuracy: 0.9784 - auc: 0.9966 - loss: 0.0765 - val_accuracy: 0.7627 - val_auc: 0.8706 - val_loss: 1.0273 - learning_rate: 5.0000e-04
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.28294
# 1658/1658 - 80s - 48ms/step - accuracy: 0.9803 - auc: 0.9972 - loss: 0.0699 - val_accuracy: 0.7608 - val_auc: 0.9104 - val_loss: 0.9545 - learning_rate: 5.0000e-04
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.28294
# 1658/1658 - 81s - 49ms/step - accuracy: 0.9817 - auc: 0.9973 - loss: 0.0644 - val_accuracy: 0.7896 - val_auc: 0.8956 - val_loss: 0.8774 - learning_rate: 5.0000e-04
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.28294
# 1658/1658 - 81s - 49ms/step - accuracy: 0.9826 - auc: 0.9976 - loss: 0.0609 - val_accuracy: 0.7616 - val_auc: 0.8734 - val_loss: 1.1081 - learning_rate: 5.0000e-04
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.28294
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1658/1658 - 80s - 48ms/step - accuracy: 0.9833 - auc: 0.9978 - loss: 0.0589 - val_accuracy: 0.7759 - val_auc: 0.8926 - val_loss: 1.0408 - learning_rate: 5.0000e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step
# ROC AUC: 0.9106270734833224
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.68      0.73      8654
#            1       0.87      0.92      0.90     20789
#
#     accuracy                           0.85     29443
#    macro avg       0.83      0.80      0.81     29443
# weighted avg       0.85      0.85      0.85     29443
#
# Confusion Matrix:
#  [[ 5904  2750]
#  [ 1673 19116]]

# %% [markdown]
# trial

# %% [markdown]
# trying

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import joblib
import matplotlib.pyplot as plt

# ==============================
# 1) DATA PREPROCESSING
# ==============================
def prepare_common_data(filepath='DataSet.csv', time_steps=50, test_size=0.2, step_size=2):
    df = pd.read_csv(filepath, low_memory=False)
    
    # Extract wrist sensor data
    df['WristAccelerometer_x'] = pd.to_numeric(df['WristAccelerometer'], errors='coerce')
    df['WristAccelerometer_y'] = pd.to_numeric(df['Unnamed: 30'], errors='coerce')
    df['WristAccelerometer_z'] = pd.to_numeric(df['Unnamed: 31'], errors='coerce')
    df['WristAngularVelocity_x'] = pd.to_numeric(df['WristAngularVelocity'], errors='coerce')
    df['WristAngularVelocity_y'] = pd.to_numeric(df['Unnamed: 33'], errors='coerce')
    df['WristAngularVelocity_z'] = pd.to_numeric(df['Unnamed: 34'], errors='coerce')

    FEATURES = ['WristAccelerometer_x','WristAccelerometer_y','WristAccelerometer_z',
                'WristAngularVelocity_x','WristAngularVelocity_y','WristAngularVelocity_z']

    # Magnitude
    df['Acc_mag'] = np.sqrt(df['WristAccelerometer_x']**2 +
                            df['WristAccelerometer_y']**2 +
                            df['WristAccelerometer_z']**2)
    df['Gyro_mag'] = np.sqrt(df['WristAngularVelocity_x']**2 +
                             df['WristAngularVelocity_y']**2 +
                             df['WristAngularVelocity_z']**2)
    FEATURES += ['Acc_mag','Gyro_mag']

    # Define Fall Now based on Tag
    FALL_CODES = [7,8,9,10,11]
    df['fall_now'] = df['Tag'].apply(lambda x: 1 if x in FALL_CODES else 0)

    # Fall Soon (predict within next HORIZON frames)
    HORIZON = 10
    fall_series = df['fall_now'].values
    df['fall_soon'] = [int(fall_series[i+1:i+HORIZON+1].max()) if i+HORIZON < len(fall_series) else 0
                       for i in range(len(fall_series))]

    df[FEATURES] = df[FEATURES].fillna(0)

    X = df[FEATURES].values
    y_now = df['fall_now'].values
    y_soon = df['fall_soon'].values

    X_train_raw, X_test_raw, y_train_now, y_test_now, y_train_soon, y_test_soon = train_test_split(
        X, y_now, y_soon, test_size=test_size, random_state=42, stratify=y_now
    )

    # Scaling
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_raw)
    X_test_scaled = scaler.transform(X_test_raw)
    joblib.dump(scaler, "scaler_all.save")

    # Sliding window
    def create_sequences(data, target, steps, step_size=1):
        X_seq, y_seq = [], []
        for i in range(0, len(data)-steps, step_size):
            X_seq.append(data[i:i+steps])
            y_seq.append(target[i+steps-1])
        return np.array(X_seq), np.array(y_seq)

    X_train, y_train_now_seq = create_sequences(X_train_scaled, y_train_now, time_steps, step_size)
    _, y_train_soon_seq = create_sequences(X_train_scaled, y_train_soon, time_steps, step_size)
    X_test, y_test_now_seq = create_sequences(X_test_scaled, y_test_now, time_steps, step_size)
    _, y_test_soon_seq = create_sequences(X_test_scaled, y_test_soon, time_steps, step_size)

    return X_train, X_test, y_train_now_seq, y_test_now_seq, y_train_soon_seq, y_test_soon_seq

# ==============================
# 2) ATTENTION BLOCK
# ==============================
def attention_block(inputs):
    score = layers.Dense(128, activation='tanh')(inputs)
    score = layers.Dense(1, activation='sigmoid')(score)
    attention = layers.Multiply()([inputs, score])
    context = layers.Lambda(lambda x: tf.reduce_sum(x, axis=1))(attention)
    return context

# ==============================
# 3) BUILD BiGRU + ATTENTION MODEL
# ==============================
def build_bigru_attention(time_steps, features):
    inp = Input(shape=(time_steps, features))
    x = layers.Bidirectional(layers.GRU(128, return_sequences=True))(inp)  # <- Apply on inp
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(0.3)(x)
    x2 = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.Add()([x, x2])
    x = layers.LayerNormalization()(x)
    att = attention_block(x)
    shared = layers.Dense(128, activation='relu')(att)
    shared = layers.Dropout(0.3)(shared)
    fall_now = layers.Dense(64, activation='relu')(shared)
    fall_now = layers.Dense(1, activation='sigmoid', name='fall_now')(fall_now)
    fall_soon = layers.Dense(64, activation='relu')(shared)
    fall_soon = layers.Dense(1, activation='sigmoid', name='fall_soon')(fall_soon)
    model = Model(inp, [fall_now, fall_soon])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(0.0008),
        loss='binary_crossentropy',
        metrics={
            "fall_now": ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
            "fall_soon": ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
        }
    )
    return model

# ==============================
# 4) TRAINING FUNCTION + EVALUATION
# ==============================
def train_bigru_attention():
    X_train, X_test, y_train_now, y_test_now, y_train_soon, y_test_soon = prepare_common_data()
    
    model = build_bigru_attention(X_train.shape[1], X_train.shape[2])
    print(model.summary())

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.4, patience=4),
        ModelCheckpoint("BEST_BiGRU_Attention.keras", save_best_only=True, monitor='val_loss')
    ]

    history = model.fit(
        X_train,
        {"fall_now": y_train_now, "fall_soon": y_train_soon},
        validation_data=(X_test, {"fall_now": y_test_now, "fall_soon": y_test_soon}),
        epochs=80,
        batch_size=128,
        callbacks=callbacks,
        verbose=1
    )

    model.save("FINAL_BiGRU_Attention.keras")

    # ==============================
    # Predictions & Metrics
    # ==============================
    y_pred_now, y_pred_soon = model.predict(X_test)
    y_pred_now = (y_pred_now>0.5).astype(int)
    y_pred_soon = (y_pred_soon>0.5).astype(int)

    for label, y_true, y_pred in [("Fall Now", y_test_now, y_pred_now), ("Fall Soon", y_test_soon, y_pred_soon)]:
        print(f"\n=== Metrics for {label} ===")
        print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
        print(f"Precision: {precision_score(y_true, y_pred):.4f}")
        print(f"Recall: {recall_score(y_true, y_pred):.4f}")
        print(f"F1-Score: {f1_score(y_true, y_pred):.4f}")
        ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred)).plot(cmap="Blues")
        plt.title(f"Confusion Matrix - {label}")
        plt.show()

    return model, history, X_test, y_test_now, y_test_soon

# ==============================
# 5) MAIN
# ==============================
if __name__=="__main__":
    train_bigru_attention()
